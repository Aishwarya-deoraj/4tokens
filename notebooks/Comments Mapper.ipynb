# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:/Users/suhaa/Desktop/Case1-4tokens/data/data_w_comments.csv')

# %%
df
# Out:
#                                        ID                          Title  \
# 0    f7121191-cbbf-4f74-8256-024ea3987b2c      Zero-Touch Purpose System
# 1    a39a9628-4938-4ccf-9f15-122aed064631       Cloud-Based Ago Analyzer
# 2    e2eb83ea-cf0f-48d0-b688-70f646ff514a           Intelligent Face Bot
# 3    356a87f2-1297-4740-8dd2-9c2fc687630d          AI-Powered Dog System
# 4    d20030cb-2356-4234-8358-2c3e87e902dc         Predictive Since Agent
# ..                                    ...                            ...
# 995  c63cbb64-ab4a-4158-8d81-71f4786da9ea     Predictive Where Dashboard
# 996  9352ea14-650b-49a7-aef3-a1cff64911db            Predictive Back Bot
# 997  993a5962-fbe2-4701-8a7c-63a056639b4f            Automated Be System
# 998  4c22f47c-3622-4a73-8c24-efa292162337  Automated Political Dashboard
# 999  b1199cb9-79da-44eb-b84f-3fa255a97e33    Zero-Touch Attorney Service
#
#                                            Description  Upvotes  \
# ...

# %%
map = dict(zip(df['ID'], df['Comments']))

# %%
map
# Out:
# {'f7121191-cbbf-4f74-8256-024ea3987b2c': "['Could drive revenue growth', 'Backed by data', 'Scalable and future-ready', 'Pilot was successful', 'Minimal maintenance overhead', 'Ambiguous requirements']",
#  'a39a9628-4938-4ccf-9f15-122aed064631': "['Could require retraining users', 'Easily integrates into workflow']",
#  'e2eb83ea-cf0f-48d0-b688-70f646ff514a': "['May duplicate existing features', 'Strong long-term value', 'Solid use case']",
#  '356a87f2-1297-4740-8dd2-9c2fc687630d': "['Needs external vendor support', 'High potential impact']",
# ...

# %%
df=pd.read_csv('C:/Users/suhaa/Desktop/Case1-4tokens/data/dependencies_supports.csv')

# %%
df
# Out:
#                                        ID                          Title  \
# 0    f7121191-cbbf-4f74-8256-024ea3987b2c      Zero-Touch Purpose System
# 1    a39a9628-4938-4ccf-9f15-122aed064631       Cloud-Based Ago Analyzer
# 2    e2eb83ea-cf0f-48d0-b688-70f646ff514a           Intelligent Face Bot
# 3    356a87f2-1297-4740-8dd2-9c2fc687630d          AI-Powered Dog System
# 4    d20030cb-2356-4234-8358-2c3e87e902dc         Predictive Since Agent
# ..                                    ...                            ...
# 995  c63cbb64-ab4a-4158-8d81-71f4786da9ea     Predictive Where Dashboard
# 996  9352ea14-650b-49a7-aef3-a1cff64911db            Predictive Back Bot
# 997  993a5962-fbe2-4701-8a7c-63a056639b4f            Automated Be System
# 998  4c22f47c-3622-4a73-8c24-efa292162337  Automated Political Dashboard
# 999  b1199cb9-79da-44eb-b84f-3fa255a97e33    Zero-Touch Attorney Service
#
#                                            Description  Upvotes  \
# ...

# %%
dependencies=dict(zip(df['ID'], df['Dependencies']))

# %%
dependencies
# Out:
# {'f7121191-cbbf-4f74-8256-024ea3987b2c': "['Automated Blue Dashboard', 'Predictive Recently Manager', 'Self-Healing Not Service', 'Intelligent Hold Service']",
#  'a39a9628-4938-4ccf-9f15-122aed064631': "['AI-Powered Total Agent', 'Self-Healing Structure Bot', 'Intelligent Generation Platform']",
#  'e2eb83ea-cf0f-48d0-b688-70f646ff514a': "['Self-Healing Result Assistant', 'Predictive Technology Dashboard', 'Predictive Condition Manager', 'Automated Back Agent', 'Self-Healing Despite Assistant']",
#  '356a87f2-1297-4740-8dd2-9c2fc687630d': "['Intelligent Development Manager', 'Self-Healing Worker Bot', 'Self-Healing Draw Manager', 'Smart Skill Service']",
#  'd20030cb-2356-4234-8358-2c3e87e902dc': "['Automated Animal Agent']",
#  '9e0faf05-f1b8-41bd-98a9-71ccb5a86864': "['Smart Husband Service', 'AI-Powered Million System', 'Self-Healing Street Service']",
# ...

# %%
supports=dict(zip(df['ID'], df['Supports']))

# %%
supports
# Out:
# {'f7121191-cbbf-4f74-8256-024ea3987b2c': "['Intelligent Choice Bot', 'Smart Rate Bot', 'Smart Expert Platform', 'AI-Powered Speak Analyzer', 'Self-Healing Cover Optimizer']",
#  'a39a9628-4938-4ccf-9f15-122aed064631': "['Intelligent Mean Assistant', 'Intelligent Tell Assistant', 'Predictive Energy Assistant']",
#  'e2eb83ea-cf0f-48d0-b688-70f646ff514a': "['Smart Training Analyzer', 'Zero-Touch Figure Analyzer', 'Intelligent Mission System', 'Smart Party Assistant', 'Intelligent Minute Optimizer']",
#  '356a87f2-1297-4740-8dd2-9c2fc687630d': "['Zero-Touch Institution Assistant', 'Self-Healing So Agent', 'Smart Game System']",
#  'd20030cb-2356-4234-8358-2c3e87e902dc': '[]',
#  '9e0faf05-f1b8-41bd-98a9-71ccb5a86864': "['Self-Healing Material Agent', 'Zero-Touch Record Bot', 'Smart Present Dashboard', 'Smart Face System', 'Cloud-Based Response Analyzer']",
# ...

# %%
ddf=pd.read_csv('C:/Users/suhaa/Desktop/Case1-4tokens/data/df_final_scoress.csv')

# %%
ddf
# Out:
#                                        ID                          Title  \
# 0    f7121191-cbbf-4f74-8256-024ea3987b2c      Zero-Touch Purpose System
# 1    a39a9628-4938-4ccf-9f15-122aed064631       Cloud-Based Ago Analyzer
# 2    e2eb83ea-cf0f-48d0-b688-70f646ff514a           Intelligent Face Bot
# 3    356a87f2-1297-4740-8dd2-9c2fc687630d          AI-Powered Dog System
# 4    d20030cb-2356-4234-8358-2c3e87e902dc         Predictive Since Agent
# ..                                    ...                            ...
# 995  c63cbb64-ab4a-4158-8d81-71f4786da9ea     Predictive Where Dashboard
# 996  9352ea14-650b-49a7-aef3-a1cff64911db            Predictive Back Bot
# 997  993a5962-fbe2-4701-8a7c-63a056639b4f            Automated Be System
# 998  4c22f47c-3622-4a73-8c24-efa292162337  Automated Political Dashboard
# 999  b1199cb9-79da-44eb-b84f-3fa255a97e33    Zero-Touch Attorney Service
#
#      Cost_Score  ROI_Score  SA_Score
# 0      0.399721   0.261409  0.629000
# ...
